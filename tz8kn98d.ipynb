# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split, cross_validate, StratifiedKFold
from sklearn.utils import resample
from sklearn.metrics import accuracy_score, roc_auc_score
import random
import sklearn

# %%
data = pd.read_csv('../input/spreadprediction/train.csv')
test = pd.read_csv('../input/spreadprediction/test.csv')

# %% [markdown]
# Посмотрим на данные, определим есть ли выбросы и насколько они пригодны для обучения.

# %%
data.describe()
# Out:
#                VASK0          VASK1          VASK2          VASK3  \
# count  186590.000000  186590.000000  186590.000000  186590.000000
# mean       92.788981     178.840495     204.462640     205.277978
# std        66.491713      62.138222      62.969816      65.644839
# min         1.000000       1.000000       5.000000       1.000000
# 25%        41.000000     138.000000     162.000000     161.000000
# 50%        83.000000     170.000000     196.000000     194.000000
# 75%       131.000000     210.000000     232.000000     234.000000
# max       647.000000     784.000000     666.000000     813.000000
#
#                VASK4          VBID0          VBID1          VBID2  \
# count  186590.000000  186590.000000  186590.000000  186590.000000
# mean      202.079436      92.270245     177.477716     203.058487
# std        67.571850      65.281200      59.409587      58.546985
# min         9.000000       1.000000       1.000000       1.000000
# 25%       156.000000      40.000000     137.000000     162.000000
# 50%       189.000000      83.000000     170.000000     197.000000
# 75%       232.000000     132.000000     211.000000     234.000000
# max       738.000000     593.000000     657.000000     683.000000
#
#                VBID3          VBID4  ...     VASK1_PREV     VASK2_PREV  \
# count  186590.000000  186590.000000  ...  186590.000000  186590.000000
# mean      202.174195     197.799646  ...     178.796431     204.430945
# std        59.286325      61.265705  ...      62.173445      62.981647
# min         4.000000       3.000000  ...       1.000000       5.000000
# 25%       161.000000     156.000000  ...     138.000000     162.000000
# 50%       195.000000     188.000000  ...     170.000000     196.000000
# 75%       233.000000     228.000000  ...     210.000000     232.000000
# max       687.000000     718.000000  ...     784.000000     666.000000
#
#           VASK3_PREV     VASK4_PREV     VBID0_PREV     VBID1_PREV  \
# count  186590.000000  186590.000000  186590.000000  186590.000000
# mean      205.273975     202.076333      92.318286     177.438491
# std        65.646947      67.573708      65.376130      59.444964
# min         1.000000       9.000000       1.000000       1.000000
# 25%       161.000000     156.000000      40.000000     136.000000
# 50%       194.000000     189.000000      83.000000     170.000000
# 75%       234.000000     232.000000     132.000000     211.000000
# max       813.000000     738.000000     593.000000     657.000000
#
#           VBID2_PREV     VBID3_PREV     VBID4_PREV              Y
# count  186590.000000  186590.000000  186590.000000  186590.000000
# mean      203.023479     202.169194     197.795123       0.010258
# std        58.557993      59.289762      61.263966       0.100760
# min         1.000000       4.000000       3.000000       0.000000
# 25%       162.000000     161.000000     156.000000       0.000000
# 50%       197.000000     195.000000     188.000000       0.000000
# 75%       234.000000     233.000000     228.000000       0.000000
# max       683.000000     687.000000     718.000000       1.000000
#
# [8 rows x 21 columns]

# %%
np.shape(data.dropna()) # пропущенных значений нет
# Out:
# (186590, 21)

# %% [markdown]
# Очевидно, что наш датасет крайне разбалансирован и если мы будем учить на нём целиком, то велика вероятность получить точность 99% при этом не угадывая ни одного представителя класса `1`. Поэтому попробуем воспользоваться различными методиками ресемплирования, предварительно отобрав в тестовый датаест по 50 представителей того и другого классов

# %%
X0_train, X0_test, y0_train, y0_test = train_test_split(data[data.Y==0].iloc[:,:-1],\
                                                        data[data.Y==0].iloc[:,-1], test_size=50, random_state=123)

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(data[data.Y==1].iloc[:,:-1],\
                                                        data[data.Y==1].iloc[:,-1], test_size=50, random_state=123)

# %%
X_train, X_test, y_train, y_test = pd.concat([X0_train, X1_train]), pd.concat([X0_test, X1_test]),\
                                    pd.concat([y0_train, y1_train]), pd.concat([y0_test, y1_test])

# %% [markdown]
# Функция ниже будет использоваться в дальнейшем для тестирования разных вариантов сэмплирования

# %%
def boosted_classifier(X, y):
    model = xgb.XGBClassifier(objective='binary:logistic', eval_metric='auc', gamma=1, min_child_weight=1, max_depth=6, \
                              learning_rate=0.01, n_estimators=100, use_label_encoder=False, \
                              subsample = 0.8, colsample_bytree=1, 
                              gpu_id=0, tree_method='gpu_hist')
    X_train_, X_test_, y_train_, y_test_ = train_test_split(X, y, test_size=0.2)
    model.fit(X_train_, y_train_)
    res = model.predict_proba(X_test_)[:,1]
    print(roc_auc_score(y_test_, res), 'auc score')
    print(roc_auc_score(y_test, model.predict(X_test)), 'auc test score')
#     print(accuracy_score(y_test, model.predict(X_test)), 'accuracy')
    return model

# %% [markdown]
# Воспользуемся методами, предлагаемыми в библиотеке imblearn, являющейся частью sklearn

# %%
from imblearn.over_sampling import RandomOverSampler

ran=RandomOverSampler()
X_ran,y_ran= ran.fit_resample(X_train,y_train)
first = boosted_classifier(X_ran, y_ran)
# Out:
# 0.902369244617882 auc score
# 0.81 auc test score

# %%
from imblearn.under_sampling import RandomUnderSampler

ran=RandomUnderSampler()
X_rs,y_rs = ran.fit_resample(X_train,y_train)
third = boosted_classifier(X_rs, y_rs)
# Out:
# 0.8913135669362083 auc score
# 0.83 auc test score

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(sampling_strategy='minority')
X_sm, y_sm = smote.fit_resample(X_train, y_train)

fourth = boosted_classifier(X_sm, y_sm)
# Out:
# 0.9171818984185642 auc score
# 0.86 auc test score

# %%
from imblearn.over_sampling import ADASYN
adasyn = ADASYN(sampling_strategy='minority')
X_ad, y_ad = adasyn.fit_resample(X_train, y_train)
fifth = boosted_classifier(X_ad, y_ad)
# Out:
# 0.9171223699010295 auc score
# 0.84 auc test score

# %% [markdown]
# Попробуем теперь произвести оптимизацию гиперпараметров

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from optuna import create_study
from optuna.samplers import TPESampler
from optuna.integration import XGBoostPruningCallback

# %%
def evaluate_model_skf(model, X_df, y_df, n_splits=5):
    X_values = X_df.values
    y_values = y_df.values
    skf = StratifiedKFold(
        n_splits=n_splits
    )
    y_pred = np.zeros((len(y_values), 2))
    
    for train_index, test_index in skf.split(X_values, y_values):
        X_A, X_B = X_values[train_index, :], X_values[test_index, :]
        y_A = y_values[train_index]
        model.fit(
            X_A, y_A,
        )
        y_pred[test_index] = model.predict_proba(X_B)
    return roc_auc_score(y_values, y_pred[:,1])

# %%
def objective(
    trial,
    X,
    y,
    random_state=22,
    n_splits=3,
    n_repeats=2,
    n_jobs=1,
    early_stopping_rounds=50,
):
    # XGBoost parameters
    params = {
        "verbosity": 0,  # 0 (silent) - 3 (debug)
        "objective": "binary:logistic",
        "n_estimators": 1000,
        "max_depth": trial.suggest_int("max_depth", 1, 12),
        "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.05),
        "colsample_bytree": trial.suggest_loguniform("colsample_bytree", 0.2, 0.6),
        "subsample": trial.suggest_loguniform("subsample", 0.4, 0.8),
        "alpha": trial.suggest_loguniform("alpha", 0.01, 10.0),
        "gamma": trial.suggest_loguniform("lambda", 1e-8, 10.0),
        "min_child_weight": trial.suggest_loguniform("min_child_weight", 10, 1000),
        "seed": random_state,
        "n_jobs": n_jobs,
    }

    model = xgb.XGBClassifier(**params, use_label_encoder=False)
    pruning_callback = XGBoostPruningCallback(trial, "validation_0-auc")
    skf = StratifiedKFold(
        n_splits=n_splits
    )
    X_values = X.values
    y_values = y.values
    y_pred = np.zeros((len(y_values), 2))
    for train_index, test_index in skf.split(X_values, y_values):
        X_A, X_B = X_values[train_index, :], X_values[test_index, :]
        y_A, y_B = y_values[train_index], y_values[test_index]
        model.fit(
            X_A,
            y_A,
            eval_set=[(X_B, y_B)],
            eval_metric="auc",
            verbose=0,
            callbacks=[pruning_callback],
            early_stopping_rounds=early_stopping_rounds,
        )
        y_pred[test_index] = model.predict_proba(X_B)
    return roc_auc_score(y_values, y_pred[:,1])

# %%
sampler = TPESampler(seed=0, multivariate=True)
study = create_study(direction="maximize", sampler=sampler)
study.optimize(
    lambda trial: objective(
        trial,
        X_rs,
        y_rs,
        random_state=0,
        n_splits=5,
        n_repeats=2,
        n_jobs=8,
        early_stopping_rounds=50,
    ),
    n_trials=100,
    n_jobs=1,
)

hp = study.best_params
for key, value in hp.items():
    print(f"{key:>20s} : {value}")
print(f"{'best objective value':>20s} : {study.best_value}")
# Out:
# [I 2021-11-24 20:14:25,053] A new study created in memory with name: no-name-f4c446b3-5291-4cde-92a2-97015e40e911
# [I 2021-11-24 20:14:26,444] Trial 0 finished with value: 0.8230645538230581 and parameters: {'max_depth': 7, 'learning_rate': 0.02595131508847582, 'colsample_bytree': 0.38781197383981786, 'subsample': 0.5835608840550383, 'alpha': 0.18662266976517972, 'lambda': 0.006502000785097662, 'min_child_weight': 75.01954443620116}. Best is trial 0 with value: 0.8230645538230581.
# [I 2021-11-24 20:14:26,914] Trial 1 finished with value: 0.5 and parameters: {'max_depth': 11, 'learning_rate': 0.04598675496284059, 'colsample_bytree': 0.3047741258042684, 'subsample': 0.6924572650469156, 'alpha': 0.3860866271460545, 'lambda': 0.001295391520396607, 'min_child_weight': 709.8936257405899}. Best is trial 0 with value: 0.8230645538230581.
# [I 2021-11-24 20:14:27,370] Trial 2 finished with value: 0.5 and parameters: {'max_depth': 1, 'learning_rate': 0.006110817364354473, 'colsample_bytree': 0.20449214141033595, 'subsample': 0.712366585029278, 'alpha': 2.1600820741402047, 'lambda': 0.6762532016190338, 'min_child_weight': 906.2263471261946}. Best is trial 0 with value: 0.8230645538230581.
# [I 2021-11-24 20:14:27,864] Trial 3 finished with value: 0.5 and parameters: {'max_depth': 10, 'learning_rate': 0.014469361482488454, 'colsample_bytree': 0.47145153663185313, 'subsample': 0.4341743284612659, 'alpha': 0.8313101133778734, 'lambda': 1.9506510537765813e-07, 'min_child_weight': 775.0644796341911}. Best is trial 0 with value: 0.8230645538230581.
# [I 2021-11-24 20:14:31,512] Trial 4 finished with value: 0.8386309841772736 and parameters: {'max_depth': 7, 'learning_rate': 0.01299068177733171, 'colsample_bytree': 0.2674576973391579, 'subsample': 0.684112546691628, 'alpha': 0.23358825194833557, 'lambda': 0.001305886823451577, 'min_child_weight': 10.903843281968525}. Best is trial 4 with value: 0.8386309841772736.
# [I 2021-11-24 20:14:32,290] Trial 5 pruned. Trial was pruned at iteration 90.
# [I 2021-11-24 20:14:34,512] Trial 6 finished with value: 0.8317763209397852 and parameters: {'max_depth': 9, 'learning_rate': 0.005743749302159308, 'colsample_bytree': 0.41606249353047675, 'subsample': 0.6367106384465745, 'alpha': 0.0427708304996207, 'lambda': 1.4465607560792659e-07, 'min_child_weight': 42.742183240368405}. Best is trial 4 with value: 0.8386309841772736.
# [I 2021-11-24 20:14:34,527] Trial 7 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:14:34,539] Trial 8 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:14:34,677] Trial 9 pruned. Trial was pruned at iteration 51.
# [I 2021-11-24 20:14:34,708] Trial 10 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:14:39,957] Trial 11 finished with value: 0.8371815653263092 and parameters: {'max_depth': 11, 'learning_rate': 0.0058600122957615, 'colsample_bytree': 0.5227133150465704, 'subsample': 0.5523683624556394, 'alpha': 0.16330371265509244, 'lambda': 1.5704356519216278e-08, 'min_child_weight': 38.07605523657218}. Best is trial 4 with value: 0.8386309841772736.
# [I 2021-11-24 20:14:39,997] Trial 12 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:14:40,051] Trial 13 pruned. Trial was pruned at iteration 3.
# [I 2021-11-24 20:14:40,083] Trial 14 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:14:40,142] Trial 15 pruned. Trial was pruned at iteration 3.
# [I 2021-11-24 20:14:40,182] Trial 16 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:14:40,232] Trial 17 pruned. Trial was pruned at iteration 3.
# [I 2021-11-24 20:14:46,017] Trial 18 finished with value: 0.8522574209324172 and parameters: {'max_depth': 9, 'learning_rate': 0.006969716702685446, 'colsample_bytree': 0.5781140370083396, 'subsample': 0.4796833363820795, 'alpha': 0.22533807494938662, 'lambda': 6.182474161714489e-06, 'min_child_weight': 10.183845679943673}. Best is trial 18 with value: 0.8522574209324172.
# [I 2021-11-24 20:14:56,180] Trial 19 finished with value: 0.8512731055094034 and parameters: {'max_depth': 6, 'learning_rate': 0.006786423311835191, 'colsample_bytree': 0.552407163770494, 'subsample': 0.5167402675484221, 'alpha': 0.3709902801530345, 'lambda': 2.431009449232247e-05, 'min_child_weight': 12.095256978771998}. Best is trial 18 with value: 0.8522574209324172.
# [I 2021-11-24 20:14:56,648] Trial 20 pruned. Trial was pruned at iteration 90.
# [I 2021-11-24 20:14:59,526] Trial 21 pruned. Trial was pruned at iteration 253.
# [I 2021-11-24 20:14:59,567] Trial 22 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:02,378] Trial 23 pruned. Trial was pruned at iteration 225.
# [I 2021-11-24 20:15:02,807] Trial 24 pruned. Trial was pruned at iteration 90.
# [I 2021-11-24 20:15:02,849] Trial 25 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:02,885] Trial 26 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:02,928] Trial 27 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:02,984] Trial 28 pruned. Trial was pruned at iteration 2.
# [I 2021-11-24 20:15:03,028] Trial 29 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:03,458] Trial 30 pruned. Trial was pruned at iteration 90.
# [I 2021-11-24 20:15:05,087] Trial 31 pruned. Trial was pruned at iteration 129.
# [I 2021-11-24 20:15:08,086] Trial 32 pruned. Trial was pruned at iteration 238.
# [I 2021-11-24 20:15:09,426] Trial 33 pruned. Trial was pruned at iteration 138.
# [I 2021-11-24 20:15:09,475] Trial 34 pruned. Trial was pruned at iteration 1.
# [I 2021-11-24 20:15:09,515] Trial 35 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:14,676] Trial 36 pruned. Trial was pruned at iteration 312.
# [I 2021-11-24 20:15:14,733] Trial 37 pruned. Trial was pruned at iteration 3.
# [I 2021-11-24 20:15:14,772] Trial 38 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:14,814] Trial 39 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:15,568] Trial 40 pruned. Trial was pruned at iteration 138.
# [I 2021-11-24 20:15:15,614] Trial 41 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:16,055] Trial 42 pruned. Trial was pruned at iteration 90.
# [I 2021-11-24 20:15:16,096] Trial 43 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:16,140] Trial 44 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:16,182] Trial 45 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:16,224] Trial 46 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:16,279] Trial 47 pruned. Trial was pruned at iteration 3.
# [I 2021-11-24 20:15:16,323] Trial 48 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:16,367] Trial 49 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:16,406] Trial 50 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:16,453] Trial 51 pruned. Trial was pruned at iteration 1.
# [I 2021-11-24 20:15:16,495] Trial 52 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:16,529] Trial 53 pruned. Trial was pruned at iteration 1.
# [I 2021-11-24 20:15:16,572] Trial 54 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:16,613] Trial 55 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:16,662] Trial 56 pruned. Trial was pruned at iteration 2.
# [I 2021-11-24 20:15:16,725] Trial 57 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:16,807] Trial 58 pruned. Trial was pruned at iteration 2.
# [I 2021-11-24 20:15:16,852] Trial 59 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:16,915] Trial 60 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:16,960] Trial 61 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:17,006] Trial 62 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:17,050] Trial 63 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:17,092] Trial 64 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:17,133] Trial 65 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:17,174] Trial 66 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:17,217] Trial 67 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:18,932] Trial 68 pruned. Trial was pruned at iteration 90.
# [I 2021-11-24 20:15:18,995] Trial 69 pruned. Trial was pruned at iteration 3.
# [I 2021-11-24 20:15:19,519] Trial 70 pruned. Trial was pruned at iteration 90.
# [I 2021-11-24 20:15:19,550] Trial 71 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:19,592] Trial 72 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:19,632] Trial 73 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:19,673] Trial 74 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:19,714] Trial 75 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:19,754] Trial 76 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:19,902] Trial 77 pruned. Trial was pruned at iteration 28.
# [I 2021-11-24 20:15:19,938] Trial 78 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:19,985] Trial 79 pruned. Trial was pruned at iteration 1.
# [I 2021-11-24 20:15:20,024] Trial 80 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:20,064] Trial 81 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:20,094] Trial 82 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:20,134] Trial 83 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:20,188] Trial 84 pruned. Trial was pruned at iteration 2.
# [I 2021-11-24 20:15:20,228] Trial 85 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:20,267] Trial 86 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:20,320] Trial 87 pruned. Trial was pruned at iteration 1.
# [I 2021-11-24 20:15:20,361] Trial 88 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:20,402] Trial 89 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:20,442] Trial 90 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:21,145] Trial 91 pruned. Trial was pruned at iteration 129.
# [I 2021-11-24 20:15:21,686] Trial 92 pruned. Trial was pruned at iteration 90.
# [I 2021-11-24 20:15:22,549] Trial 93 pruned. Trial was pruned at iteration 129.
# [I 2021-11-24 20:15:23,418] Trial 94 pruned. Trial was pruned at iteration 129.
# [I 2021-11-24 20:15:23,449] Trial 95 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:23,488] Trial 96 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:26,440] Trial 97 pruned. Trial was pruned at iteration 253.
# [I 2021-11-24 20:15:26,472] Trial 98 pruned. Trial was pruned at iteration 0.
# [I 2021-11-24 20:15:26,514] Trial 99 pruned. Trial was pruned at iteration 0.
#            max_depth : 9
#        learning_rate : 0.006969716702685446
#     colsample_bytree : 0.5781140370083396
#            subsample : 0.4796833363820795
#                alpha : 0.22533807494938662
#               lambda : 6.182474161714489e-06
#     min_child_weight : 10.183845679943673
# best objective value : 0.8522574209324172

# %%
hp['num_estimators'] = 1000
model_optimized = xgb.XGBClassifier(**hp).fit(X_ran, y_ran)
res = model_optimized.predict(X_test)
accuracy_score(y_test, res)
# Out:
# 0.81

# %% [markdown]
# Будем пользоваться моделью, давшей лучший результат на тестовой выборке (пятой)

# %%
predictions = fifth.predict_proba(test)

# %%
def foo(x):
    if 0.2 <= abs(x) <= 0.4:
        return 0.5
    else:
        if x > 0:
            return 0
        else:
            return 1

# %%
pred = pd.DataFrame(predictions)

# %%
pred['diff'] = pred.apply(lambda x: x[0]-x[1], axis=1)

# %%
pred['res'] = pred['diff'].apply(foo)

# %%
pred['res'].to_csv('prediction.csv')
